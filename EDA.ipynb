# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Disease + Symptoms Dataset

# %%
data = pd.read_csv('./Data/dataset.csv', sep = ',')

# %%
data
# Out:
#                                       Disease             Symptom 1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin rash
# 4917                  Urinary tract infection   burning micturition
# 4918                                Psoriasis             skin rash
# 4919                                 Impetigo             skin rash
#
#                   Symptom 2              Symptom 3                  Symptom 4  \
# ...

# %%
print('Total number of lines:', data.duplicated(keep='first').count())
print('Number of reapeated lines:', data.duplicated().sum())
# Out:
# Total number of lines: 4920
# Number of reapeated lines: 4616

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom 1   4920 non-null   object
#  2   Symptom 2   4920 non-null   object
#  3   Symptom 3   4920 non-null   object
#  4   Symptom 4   4572 non-null   object
#  5   Symptom 5   3714 non-null   object
#  6   Symptom 6   2934 non-null   object
#  7   Symptom 7   2268 non-null   object
#  8   Symptom 8   1944 non-null   object
#  9   Symptom 9   1692 non-null   object
#  10  Symptom 10  1512 non-null   object
#  11  Symptom 11  1194 non-null   object
#  12  Symptom 12  744 non-null    object
#  13  Symptom 13  504 non-null    object
#  14  Symptom 14  306 non-null    object
#  15  Symptom 15  240 non-null    object
#  16  Symptom 16  192 non-null    object
#  17  Symptom 17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
data.describe()
# Out:
#                Disease  Symptom 1  Symptom 2 Symptom 3    Symptom 4  \
# count             4920       4920       4920      4920         4572
# unique              41         34         48        54           50
# top     Varicose veins   vomiting   vomiting   fatigue   high fever
# freq               120        822        870       726          378
#
#         Symptom 5 Symptom 6        Symptom 7        Symptom 8  \
# count        3714      2934             2268             1944
# unique         38        32               26               21
# top      headache    nausea   abdominal pain   abdominal pain
# freq          348       390              264              276
#
#                  Symptom 9          Symptom 10     Symptom 11 Symptom 12  \
# count                 1692                1512           1194        744
# unique                  22                  21             18         11
# top      yellowing of eyes   yellowing of eyes   irritability    malaise
# ...

# %%
data.isna().sum()
# Out:
# Disease          0
# Symptom 1        0
# Symptom 2        0
# Symptom 3        0
# Symptom 4      348
# Symptom 5     1206
# Symptom 6     1986
# Symptom 7     2652
# Symptom 8     2976
# Symptom 9     3228
# Symptom 10    3408
# Symptom 11    3726
# Symptom 12    4176
# Symptom 13    4416
# Symptom 14    4614
# Symptom 15    4680
# Symptom 16    4728
# Symptom 17    4848
# dtype: int64

# %% [markdown]
# ### Details about diseases

# %%
diseases = data['Disease'].unique()
print('There are', len(diseases), 'diseases in the dataset')
# Out:
# There are 41 diseases in the dataset

# %% [markdown]
# #### number of entries per disease in the dataset

# %%
data['Disease'].value_counts()
# Out:
# Varicose veins                             120
# Paralysis (brain hemorrhage)               120
# Chicken pox                                120
# Jaundice                                   120
# Impetigo                                   120
# Hepatitis B                                120
# Urinary tract infection                    120
# (vertigo) Paroymsal  Positional Vertigo    120
# Osteoarthristis                            120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# Hyperthyroidism                            120
# Cervical spondylosis                       120
# Hepatitis C                                120
# Gastroenteritis                            120
# Diabetes                                   120
# Tuberculosis                               120
# Allergy                                    120
# Common Cold                                120
# ...

# %% [markdown]
# ### Details about symptoms

# %%
symptoms = data.drop('Disease',1)

for column in symptoms:
    s = np.append(s, symptoms.values)
    
for symptom in s:
    if symptom not in uniques:
        uniques.append(symptom)

symptom_list = [x for x in uniques if str(x) != 'nan']
#print(symptom_list)
        
print('There are',len(symptom_list),'different symptoms in the dataset')
# Out:
# There are 131 different symptoms in the dataset

# %%
for column in symptoms:
    print(symptoms[column].value_counts())
# Out:
#  vomiting                       822
#  fatigue                        690
# itching                         678
#  skin rash                      480
#  chills                         474
#  joint pain                     462
#  continuous sneezing            222
#  headache                       126
#  acidity                        120
#  stomach pain                   114
#  muscle weakness                114
#  constipation                   114
#  burning micturition            108
#  muscle wasting                 108
#  back pain                      108
#  yellowish skin                  12
#  indigestion                     12
#  patches in throat               12
#  sunken eyes                     12
#  bladder discomfort              12
#  weakness in limbs               12
#  shivering                       12
#  breathlessness                  12
#  cough                           12
#  chest pain                      12
#  weight gain                     12
# ...

# %% [markdown]
# #### remove last column because it's empty

# %%
data.drop('Symptom 17', 1)
symptoms.drop('Symptom 17', 1)
# Out:
#                  Symptom 1              Symptom 2              Symptom 3  \
# 0                  itching              skin rash   nodal skin eruptions
# 1                skin rash   nodal skin eruptions     dischromic patches
# 2                  itching   nodal skin eruptions     dischromic patches
# 3                  itching              skin rash     dischromic patches
# 4                  itching              skin rash   nodal skin eruptions
# ...                    ...                    ...                    ...
# 4915              vomiting               headache                 nausea
# 4916             skin rash     pus filled pimples             blackheads
# 4917   burning micturition     bladder discomfort     foul smell ofurine
# 4918             skin rash             joint pain           skin peeling
# 4919             skin rash             high fever                blister
#
#                       Symptom 4              Symptom 5            Symptom 6  \
# ...

# %% [markdown]
# ## Load Symptom Severity Dataset

# %%
severity = pd.read_csv('./Data/Symptom-severity.csv')

# %%
severity.head()
# Out:
#                 Symptom  Weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
severity.describe()
# Out:
#            Weight
# count  131.000000
# mean     4.213740
# std      1.324373
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      7.000000

# %%
severity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symptom  131 non-null    object
#  1   Weight   131 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
severity.isna().sum()
# Out:
# Symptom    0
# Weight     0
# dtype: int64

# %%
print('There are', len(severity['Symptom'].unique()), 'symptoms in the dataset')
# Out:
# There are 131 symptoms in the dataset

# %%
print('Severity Scale:',severity['Weight'].unique())
# Out:
# Severity Scale: [1 3 4 5 6 2 7]

# %%
severity['Weight'].value_counts()
# Out:
# 4    38
# 5    35
# 3    21
# 6    16
# 2    15
# 7     5
# 1     1
# Name: Weight, dtype: int64

# %%
x = ['1', '2', '3', '4', '5', '6', '7']
scale = [1, 15, 21, 38, 35, 16, 5]
c = ["indigo","mediumvioletred","thistle", "plum", "slateblue", "darkorchid", "darkmagenta"]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, scale, color=c)
plt.xlabel("Scale")
plt.ylabel("Number of occurrences")
plt.title("Number of occurrences of each number in the scale")

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# ## Load Exam Mapping Dataset

# %%
exams = pd.read_csv('./Data/map.csv', sep = ';')

# %%
exams.head()
# Out:
#           Disease                  Exam1                       Exam2  \
# 0   Drug Reaction            Blood Tests                 Skin biopsy
# 1         Malaria            Blood Tests  Complete blood count (CBC)
# 2         Allergy  Skin Prick Test (SPT)       Intradermal Skin Test
# 3  Hypothyroidism               TSH test                     T4 test
# 4       Psoriasis            Skin biopsy        Physical Examination
#
#                              Exam3                 Exam4 Exam5 Exam6 Exam7
# 0                       Patch test                   NaN   NaN   NaN   NaN
# 1  Polymerase chain reaction (PCR)                   NaN   NaN   NaN   NaN
# 2                      Blood Tests  Physical Examination   NaN   NaN   NaN
# 3                     Thyroid scan    Thyroid ultrasound   NaN   NaN   NaN
# 4                              NaN                   NaN   NaN   NaN   NaN

# %%
exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Disease  41 non-null     object
#  1   Exam1    41 non-null     object
#  2   Exam2    39 non-null     object
#  3   Exam3    34 non-null     object
#  4   Exam4    29 non-null     object
#  5   Exam5    20 non-null     object
#  6   Exam6    13 non-null     object
#  7   Exam7    2 non-null      object
# dtypes: object(8)
# memory usage: 2.7+ KB

# %%
exams.describe()
# Out:
#          Disease                 Exam1        Exam2     Exam3        Exam4  \
# count         41                    41           39        34           29
# unique        41                    21           29        26           22
# top     Migraine  Physical Examination  Blood Tests  MRI Scan  Blood Tests
# freq           1                    12            9         4            5
#
#            Exam5    Exam6        Exam7
# count         20       13            2
# unique        18       10            2
# top     MRI Scan  CT Scan  Gram Strain
# freq           3        3            1

# %%
exams.isna().sum()
# Out:
# Disease     0
# Exam1       0
# Exam2       2
# Exam3       7
# Exam4      12
# Exam5      21
# Exam6      28
# Exam7      39
# dtype: int64

# %%
exam = exams.drop('Disease',1)
e = []
unique = []
for c in exam:
    np.append(e, exam.values)
    e = np.concatenate(exam.values, axis = 0)

exams_list = [x for x in e if str(x) != 'nan']

for ex in e: 
    if ex not in unique:
        unique.append(ex)

exam_list = [x for x in unique if str(x) != 'nan']
#print(exam_list)

print('There are',len(exam_list),'different exams in the dataset')
# Out:
# There are 102 different exams in the dataset

# %%
len(exams_list)
# Out:
# 178

# %%
for elem in exam_list:
    exams_list.count(elem)
    print(exams_list.count(elem),'-', elem,)
# Out:
# 24 - Blood Tests
# 2 - Skin biopsy
# 1 - Patch test
# 1 - Complete blood count (CBC)
# 1 - Polymerase chain reaction (PCR)
# 1 - Skin Prick Test (SPT)
# 1 - Intradermal Skin Test
# 15 - Physical Examination
# 2 - TSH test
# 2 - T4 test
# 2 - Thyroid scan
# 2 - Thyroid ultrasound
# 1 - Esophagram
# 1 - Esophageal manometry
# 1 - pH monitoring
# 1 - Endoscopy
# 1 - Biopsy of upper disgestive system
# 1 - X-ray of upper digestive system
# 3 - Serum bilirubin test
# 2 - Serum albumin test
# 2 - Serum alkaline phosphatase test
# 1 - Serum aminotransferases (transaminases)
# 1 - Prothrombin time (PTT) test
# 1 - Alanine transaminase (ALT) test
# 3 - Liver Ultrasound
# 3 - Liver Biopsy
# 8 - MRI Scan
# 5 - CT Scan
# 1 - X-ray
# 1 - Electronystagmography (ENG)
# 1 - Videonystagmography (VNG)
# 1 - Fasting plasma glucose (FPG) test
# 1 - Hemoglobin A1C test
# 1 - Random plasma glucose (RPG) test
# 1 - Blood Test
# 2 - Electrocardiogram (ECG)
# 3 - Echocardiogram
# 1 - Ambulatory monitoring
# ...

# %%
labels = 'Blood Tests', 'MRI Scan', 'CT Scan', 'Chest X-ray', 'Physical Examination', 'Others'
sizes = [23.52, 7.84, 8.82, 3.92, 14.71, 40.19]
c = ["thistle", "plum", "slateblue", "darkorchid", "darkmagenta", 'mediumpurple']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', colors = c, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Most Commonly Prescribed Medical Exams")

plt.show()
